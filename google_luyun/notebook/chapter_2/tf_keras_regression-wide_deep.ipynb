# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import sys
import time
import sklearn
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for model in mpl, np, pd, sklearn, keras:
    print(model.__name__, model.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=7, micro=7, releaselevel='final', serial=0)
# matplotlib 3.2.2
# numpy 1.19.0
# pandas 1.0.5
# sklearn 0.23.1
# tensorflow_core.keras 2.2.4-tf

# %%
# 回归问题
# 加利福利亚
from sklearn.datasets import fetch_california_housing
#加载数据
housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
import pprint
#展示数据 查看规律
pprint.pprint(housing.data[0:5])
pprint.pprint(housing.target[0:5])
# Out:
# array([[ 8.32520000e+00,  4.10000000e+01,  6.98412698e+00,
#          1.02380952e+00,  3.22000000e+02,  2.55555556e+00,
#          3.78800000e+01, -1.22230000e+02],
#        [ 8.30140000e+00,  2.10000000e+01,  6.23813708e+00,
#          9.71880492e-01,  2.40100000e+03,  2.10984183e+00,
#          3.78600000e+01, -1.22220000e+02],
#        [ 7.25740000e+00,  5.20000000e+01,  8.28813559e+00,
#          1.07344633e+00,  4.96000000e+02,  2.80225989e+00,
#          3.78500000e+01, -1.22240000e+02],
#        [ 5.64310000e+00,  5.20000000e+01,  5.81735160e+00,
#          1.07305936e+00,  5.58000000e+02,  2.54794521e+00,
#          3.78500000e+01, -1.22250000e+02],
#        [ 3.84620000e+00,  5.20000000e+01,  6.28185328e+00,
#          1.08108108e+00,  5.65000000e+02,  2.18146718e+00,
#          3.78500000e+01, -1.22250000e+02]])
# array([4.526, 3.585, 3.521, 3.413, 3.422])

# %%
from sklearn.model_selection import train_test_split

#数据切割 训练集 验证集 测试
x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data, housing.target, random_state=7, test_size=0.25)
x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all, random_state=11)

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

#数据归一化
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled =  scaler.transform(x_test)

# %%
# 函数式API
# 构建 wide&deep模型
input = keras.layers.Input(shape=x_train.shape[1:]) #wide
# deep
hidden1 = keras.layers.Dense(30,activation='relu')(input)
hidden2 = keras.layers.Dense(30,activation='relu')(hidden1)
# concatenate
concat = keras.layers.concatenate([input,hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs= [input], outputs= [output])


model.summary()
model.compile(loss='mean_squared_error', optimizer='Adagrad', metrics=['accuracy'])

logdir = os.path.join('wide-deep-callbacks')
if not os.path.exists(logdir):
    os.mkdir(logdir)

callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3),
             keras.callbacks.TensorBoard(logdir)]
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 30)           930         dense[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(x_train_scaled,y_train, validation_data = (x_valid_scaled,y_valid), epochs=100, callbacks = callbacks)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 2s 202us/sample - loss: 4.1019 - accuracy: 0.0026 - val_loss: 3.5469 - val_accuracy: 0.0023
# Epoch 2/100
# 11610/11610 [==============================] - 1s 106us/sample - loss: 2.8562 - accuracy: 0.0031 - val_loss: 2.7339 - val_accuracy: 0.0023
# Epoch 3/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 2.2812 - accuracy: 0.0031 - val_loss: 2.2723 - val_accuracy: 0.0023
# Epoch 4/100
# 11610/11610 [==============================] - 1s 100us/sample - loss: 1.9352 - accuracy: 0.0031 - val_loss: 1.9649 - val_accuracy: 0.0023
# Epoch 5/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 1.6990 - accuracy: 0.0031 - val_loss: 1.7446 - val_accuracy: 0.0023
# Epoch 6/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 1.5262 - accuracy: 0.0031 - val_loss: 1.5763 - val_accuracy: 0.0023
# Epoch 7/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 1.3916 - accuracy: 0.0031 - val_loss: 1.4416 - val_accuracy: 0.0023
# Epoch 8/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 1.2820 - accuracy: 0.0031 - val_loss: 1.3299 - val_accuracy: 0.0023
# Epoch 9/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 1.1901 - accuracy: 0.0031 - val_loss: 1.2334 - val_accuracy: 0.0023
# Epoch 10/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 1.1124 - accuracy: 0.0031 - val_loss: 1.1517 - val_accuracy: 0.0023
# Epoch 11/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 1.0471 - accuracy: 0.0031 - val_loss: 1.0852 - val_accuracy: 0.0023
# Epoch 12/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.9933 - accuracy: 0.0031 - val_loss: 1.0311 - val_accuracy: 0.0023
# Epoch 13/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.9487 - accuracy: 0.0031 - val_loss: 0.9863 - val_accuracy: 0.0023
# Epoch 14/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.9113 - accuracy: 0.0031 - val_loss: 0.9490 - val_accuracy: 0.0021
# Epoch 15/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.8796 - accuracy: 0.0031 - val_loss: 0.9174 - val_accuracy: 0.0021
# Epoch 16/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.8525 - accuracy: 0.0031 - val_loss: 0.8904 - val_accuracy: 0.0021
# Epoch 17/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.8291 - accuracy: 0.0031 - val_loss: 0.8670 - val_accuracy: 0.0021
# Epoch 18/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.8086 - accuracy: 0.0031 - val_loss: 0.8467 - val_accuracy: 0.0021
# Epoch 19/100
# 11610/11610 [==============================] - 1s 83us/sample - loss: 0.7904 - accuracy: 0.0031 - val_loss: 0.8287 - val_accuracy: 0.0021
# Epoch 20/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.7743 - accuracy: 0.0031 - val_loss: 0.8128 - val_accuracy: 0.0021
# Epoch 21/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.7599 - accuracy: 0.0031 - val_loss: 0.7986 - val_accuracy: 0.0021
# Epoch 22/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.7468 - accuracy: 0.0030 - val_loss: 0.7859 - val_accuracy: 0.0021
# Epoch 23/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.7348 - accuracy: 0.0030 - val_loss: 0.7743 - val_accuracy: 0.0021
# Epoch 24/100
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.7239 - accuracy: 0.0030 - val_loss: 0.7637 - val_accuracy: 0.0021
# Epoch 25/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.7138 - accuracy: 0.0030 - val_loss: 0.7540 - val_accuracy: 0.0021
# Epoch 26/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.7044 - accuracy: 0.0030 - val_loss: 0.7449 - val_accuracy: 0.0021
# Epoch 27/100
# 11610/11610 [==============================] - 1s 124us/sample - loss: 0.6956 - accuracy: 0.0030 - val_loss: 0.7365 - val_accuracy: 0.0021
# Epoch 28/100
# 11610/11610 [==============================] - 1s 102us/sample - loss: 0.6874 - accuracy: 0.0030 - val_loss: 0.7286 - val_accuracy: 0.0021
# Epoch 29/100
# 11610/11610 [==============================] - 1s 107us/sample - loss: 0.6797 - accuracy: 0.0030 - val_loss: 0.7211 - val_accuracy: 0.0021
# Epoch 30/100
# 11610/11610 [==============================] - 2s 145us/sample - loss: 0.6724 - accuracy: 0.0030 - val_loss: 0.7141 - val_accuracy: 0.0021
# Epoch 31/100
# 11610/11610 [==============================] - 1s 97us/sample - loss: 0.6656 - accuracy: 0.0030 - val_loss: 0.7074 - val_accuracy: 0.0021
# Epoch 32/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.6590 - accuracy: 0.0030 - val_loss: 0.7011 - val_accuracy: 0.0021
# Epoch 33/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.6527 - accuracy: 0.0030 - val_loss: 0.6950 - val_accuracy: 0.0021
# Epoch 34/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.6468 - accuracy: 0.0030 - val_loss: 0.6892 - val_accuracy: 0.0021
# Epoch 35/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.6411 - accuracy: 0.0030 - val_loss: 0.6836 - val_accuracy: 0.0021
# Epoch 36/100
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.6356 - accuracy: 0.0030 - val_loss: 0.6782 - val_accuracy: 0.0021
# Epoch 37/100
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.6303 - accuracy: 0.0030 - val_loss: 0.6731 - val_accuracy: 0.0021
# Epoch 38/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.6253 - accuracy: 0.0030 - val_loss: 0.6681 - val_accuracy: 0.0021
# Epoch 39/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.6204 - accuracy: 0.0030 - val_loss: 0.6632 - val_accuracy: 0.0021
# Epoch 40/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.6158 - accuracy: 0.0030 - val_loss: 0.6586 - val_accuracy: 0.0021
# Epoch 41/100
# 11610/11610 [==============================] - 1s 102us/sample - loss: 0.6113 - accuracy: 0.0030 - val_loss: 0.6541 - val_accuracy: 0.0021
# Epoch 42/100
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.6069 - accuracy: 0.0030 - val_loss: 0.6498 - val_accuracy: 0.0021
# Epoch 43/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.6027 - accuracy: 0.0030 - val_loss: 0.6455 - val_accuracy: 0.0021
# Epoch 44/100
# 11610/11610 [==============================] - 1s 123us/sample - loss: 0.5987 - accuracy: 0.0030 - val_loss: 0.6414 - val_accuracy: 0.0021
# Epoch 45/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.5947 - accuracy: 0.0030 - val_loss: 0.6374 - val_accuracy: 0.0021
# Epoch 46/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.5909 - accuracy: 0.0030 - val_loss: 0.6335 - val_accuracy: 0.0021
# Epoch 47/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.5872 - accuracy: 0.0030 - val_loss: 0.6298 - val_accuracy: 0.0021
# Epoch 48/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.5837 - accuracy: 0.0030 - val_loss: 0.6261 - val_accuracy: 0.0021
# Epoch 49/100
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.5802 - accuracy: 0.0030 - val_loss: 0.6225 - val_accuracy: 0.0021
# Epoch 50/100
# 11610/11610 [==============================] - 1s 108us/sample - loss: 0.5769 - accuracy: 0.0030 - val_loss: 0.6191 - val_accuracy: 0.0021
# Epoch 51/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.5736 - accuracy: 0.0030 - val_loss: 0.6157 - val_accuracy: 0.0021
# Epoch 52/100
# 11610/11610 [==============================] - 1s 97us/sample - loss: 0.5705 - accuracy: 0.0030 - val_loss: 0.6124 - val_accuracy: 0.0021
# Epoch 53/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5674 - accuracy: 0.0030 - val_loss: 0.6092 - val_accuracy: 0.0021
# Epoch 54/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5644 - accuracy: 0.0030 - val_loss: 0.6061 - val_accuracy: 0.0021
# Epoch 55/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.5615 - accuracy: 0.0030 - val_loss: 0.6031 - val_accuracy: 0.0021
# Epoch 56/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.5587 - accuracy: 0.0030 - val_loss: 0.6001 - val_accuracy: 0.0021
# Epoch 57/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.5559 - accuracy: 0.0030 - val_loss: 0.5972 - val_accuracy: 0.0021
# Epoch 58/100
# 11610/11610 [==============================] - 1s 107us/sample - loss: 0.5532 - accuracy: 0.0030 - val_loss: 0.5944 - val_accuracy: 0.0021
# Epoch 59/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.5506 - accuracy: 0.0030 - val_loss: 0.5916 - val_accuracy: 0.0021
# Epoch 60/100
# 11610/11610 [==============================] - 1s 109us/sample - loss: 0.5480 - accuracy: 0.0030 - val_loss: 0.5889 - val_accuracy: 0.0021
# Epoch 61/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.5455 - accuracy: 0.0030 - val_loss: 0.5863 - val_accuracy: 0.0021
# Epoch 62/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.5431 - accuracy: 0.0030 - val_loss: 0.5837 - val_accuracy: 0.0021
# Epoch 63/100
# 11610/11610 [==============================] - 2s 130us/sample - loss: 0.5407 - accuracy: 0.0030 - val_loss: 0.5811 - val_accuracy: 0.0021
# Epoch 64/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.5384 - accuracy: 0.0030 - val_loss: 0.5787 - val_accuracy: 0.0021
# Epoch 65/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.5361 - accuracy: 0.0030 - val_loss: 0.5762 - val_accuracy: 0.0021
# Epoch 66/100
# 11610/11610 [==============================] - 1s 102us/sample - loss: 0.5339 - accuracy: 0.0030 - val_loss: 0.5738 - val_accuracy: 0.0021
# Epoch 67/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.5317 - accuracy: 0.0030 - val_loss: 0.5715 - val_accuracy: 0.0021
# Epoch 68/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5296 - accuracy: 0.0030 - val_loss: 0.5692 - val_accuracy: 0.0021
# Epoch 69/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.5275 - accuracy: 0.0030 - val_loss: 0.5670 - val_accuracy: 0.0021
# Epoch 70/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.5254 - accuracy: 0.0030 - val_loss: 0.5647 - val_accuracy: 0.0021
# Epoch 71/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5234 - accuracy: 0.0031 - val_loss: 0.5626 - val_accuracy: 0.0021
# Epoch 72/100
# 11610/11610 [==============================] - 1s 107us/sample - loss: 0.5215 - accuracy: 0.0031 - val_loss: 0.5604 - val_accuracy: 0.0021
# Epoch 73/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.5195 - accuracy: 0.0031 - val_loss: 0.5584 - val_accuracy: 0.0021
# Epoch 74/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.5176 - accuracy: 0.0031 - val_loss: 0.5563 - val_accuracy: 0.0021
# Epoch 75/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.5158 - accuracy: 0.0031 - val_loss: 0.5543 - val_accuracy: 0.0021
# Epoch 76/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.5140 - accuracy: 0.0031 - val_loss: 0.5524 - val_accuracy: 0.0021
# Epoch 77/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.5122 - accuracy: 0.0031 - val_loss: 0.5504 - val_accuracy: 0.0021
# Epoch 78/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.5105 - accuracy: 0.0031 - val_loss: 0.5485 - val_accuracy: 0.0021
# Epoch 79/100
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.5088 - accuracy: 0.0031 - val_loss: 0.5467 - val_accuracy: 0.0021
# Epoch 80/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.5071 - accuracy: 0.0031 - val_loss: 0.5448 - val_accuracy: 0.0021
# Epoch 81/100
# 11610/11610 [==============================] - 1s 115us/sample - loss: 0.5055 - accuracy: 0.0031 - val_loss: 0.5430 - val_accuracy: 0.0021
# Epoch 82/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.5039 - accuracy: 0.0031 - val_loss: 0.5413 - val_accuracy: 0.0021
# Epoch 83/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.5023 - accuracy: 0.0031 - val_loss: 0.5396 - val_accuracy: 0.0021
# Epoch 84/100
# 11610/11610 [==============================] - 2s 142us/sample - loss: 0.5007 - accuracy: 0.0031 - val_loss: 0.5379 - val_accuracy: 0.0021
# Epoch 85/100
# 11610/11610 [==============================] - 2s 156us/sample - loss: 0.4992 - accuracy: 0.0031 - val_loss: 0.5362 - val_accuracy: 0.0021
# Epoch 86/100
# 11610/11610 [==============================] - 1s 128us/sample - loss: 0.4977 - accuracy: 0.0031 - val_loss: 0.5345 - val_accuracy: 0.0021
# Epoch 87/100
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.4963 - accuracy: 0.0031 - val_loss: 0.5329 - val_accuracy: 0.0021
# Epoch 88/100
# 11610/11610 [==============================] - 2s 145us/sample - loss: 0.4948 - accuracy: 0.0031 - val_loss: 0.5313 - val_accuracy: 0.0021
# Epoch 89/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.4934 - accuracy: 0.0031 - val_loss: 0.5298 - val_accuracy: 0.0021
# Epoch 90/100
# 11610/11610 [==============================] - 1s 127us/sample - loss: 0.4920 - accuracy: 0.0031 - val_loss: 0.5283 - val_accuracy: 0.0021
# Epoch 91/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.4906 - accuracy: 0.0031 - val_loss: 0.5267 - val_accuracy: 0.0021
# Epoch 92/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.4893 - accuracy: 0.0031 - val_loss: 0.5252 - val_accuracy: 0.0021
# Epoch 93/100
# 11610/11610 [==============================] - 1s 118us/sample - loss: 0.4880 - accuracy: 0.0031 - val_loss: 0.5238 - val_accuracy: 0.0021
# Epoch 94/100
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.4867 - accuracy: 0.0031 - val_loss: 0.5223 - val_accuracy: 0.0021
# Epoch 95/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.4854 - accuracy: 0.0031 - val_loss: 0.5209 - val_accuracy: 0.0021
# Epoch 96/100
# 11610/11610 [==============================] - 1s 97us/sample - loss: 0.4841 - accuracy: 0.0031 - val_loss: 0.5195 - val_accuracy: 0.0021
# Epoch 97/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.4829 - accuracy: 0.0031 - val_loss: 0.5181 - val_accuracy: 0.0021
# Epoch 98/100
# 11610/11610 [==============================] - 1s 97us/sample - loss: 0.4817 - accuracy: 0.0031 - val_loss: 0.5168 - val_accuracy: 0.0021
# Epoch 99/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.4805 - accuracy: 0.0031 - val_loss: 0.5154 - val_accuracy: 0.0021
# Epoch 100/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.4793 - accuracy: 0.0031 - val_loss: 0.5141 - val_accuracy: 0.0021

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
