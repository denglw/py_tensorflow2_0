# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import sys
import time
import sklearn
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for model in mpl, np, pd, sklearn, keras:
    print(model.__name__, model.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=7, micro=7, releaselevel='final', serial=0)
# matplotlib 3.2.2
# numpy 1.19.0
# pandas 1.0.5
# sklearn 0.23.1
# tensorflow_core.keras 2.2.4-tf

# %%
# 回归问题
# 加利福利亚
from sklearn.datasets import fetch_california_housing
#加载数据
housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
import pprint
#展示数据 查看规律
pprint.pprint(housing.data[0:5])
pprint.pprint(housing.target[0:5])
# Out:
# array([[ 8.32520000e+00,  4.10000000e+01,  6.98412698e+00,
#          1.02380952e+00,  3.22000000e+02,  2.55555556e+00,
#          3.78800000e+01, -1.22230000e+02],
#        [ 8.30140000e+00,  2.10000000e+01,  6.23813708e+00,
#          9.71880492e-01,  2.40100000e+03,  2.10984183e+00,
#          3.78600000e+01, -1.22220000e+02],
#        [ 7.25740000e+00,  5.20000000e+01,  8.28813559e+00,
#          1.07344633e+00,  4.96000000e+02,  2.80225989e+00,
#          3.78500000e+01, -1.22240000e+02],
#        [ 5.64310000e+00,  5.20000000e+01,  5.81735160e+00,
#          1.07305936e+00,  5.58000000e+02,  2.54794521e+00,
#          3.78500000e+01, -1.22250000e+02],
#        [ 3.84620000e+00,  5.20000000e+01,  6.28185328e+00,
#          1.08108108e+00,  5.65000000e+02,  2.18146718e+00,
#          3.78500000e+01, -1.22250000e+02]])
# array([4.526, 3.585, 3.521, 3.413, 3.422])

# %%
from sklearn.model_selection import train_test_split

#数据切割 训练集 验证集 测试
x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data, housing.target, random_state=7, test_size=0.25)
x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all, random_state=11)

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

#数据归一化
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled =  scaler.transform(x_test)

# %%
# 子类API    
# WideDeepModel 继承 Model
class WideDeepModel(keras.models.Model):
    def __init__(self):
        super(WideDeepModel,self).__init__()
        """定义模型的层次"""
        self.hidden1_layer = keras.layers.Dense(30,activation='relu')
        self.hidden2_layer = keras.layers.Dense(30,activation='relu')
        self.output_layer = keras.layers.Dense(1)
        
    def call(self,input):
        """完成模型 正向计算"""
        hidden1 = self.hidden1_layer(input)
        hidden2 = self.hidden2_layer(hidden1)
        concat = keras.layers.concatenate([input,hidden2])
        output = self.output_layer(concat)
        return output
    
model = WideDeepModel()
model.build(input_shape=(None,8))


model.summary()
model.compile(loss='mean_squared_error', optimizer='Adagrad', metrics=['accuracy'])

logdir = os.path.join('wide-deep-subclass-callbacks')
if not os.path.exists(logdir):
    os.mkdir(logdir)

callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-2),
             keras.callbacks.TensorBoard(logdir)]
# Out:
# Model: "wide_deep_model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              multiple                  270
# _________________________________________________________________
# dense_7 (Dense)              multiple                  930
# _________________________________________________________________
# dense_8 (Dense)              multiple                  39
# =================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaled,y_train, validation_data = (x_valid_scaled,y_valid), epochs=20, callbacks = callbacks)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 3s 244us/sample - loss: 3.8242 - accuracy: 0.0022 - val_loss: 2.6604 - val_accuracy: 0.0021
# Epoch 2/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 2.1206 - accuracy: 0.0030 - val_loss: 1.6433 - val_accuracy: 0.0023
# Epoch 3/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 1.5111 - accuracy: 0.0030 - val_loss: 1.2776 - val_accuracy: 0.0023
# Epoch 4/100
# 11610/11610 [==============================] - 1s 100us/sample - loss: 1.2665 - accuracy: 0.0031 - val_loss: 1.1178 - val_accuracy: 0.0023
# Epoch 5/100
# 11610/11610 [==============================] - 1s 107us/sample - loss: 1.1457 - accuracy: 0.0031 - val_loss: 1.0317 - val_accuracy: 0.0023
# Epoch 6/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 1.0724 - accuracy: 0.0031 - val_loss: 0.9762 - val_accuracy: 0.0023
# Epoch 7/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 1.0215 - accuracy: 0.0031 - val_loss: 0.9362 - val_accuracy: 0.0023
# Epoch 8/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.9836 - accuracy: 0.0030 - val_loss: 0.9059 - val_accuracy: 0.0021
# Epoch 9/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.9542 - accuracy: 0.0030 - val_loss: 0.8825 - val_accuracy: 0.0021
# Epoch 10/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.9307 - accuracy: 0.0030 - val_loss: 0.8636 - val_accuracy: 0.0021
# Epoch 11/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.9111 - accuracy: 0.0030 - val_loss: 0.8480 - val_accuracy: 0.0021
# Epoch 12/100
# 11610/11610 [==============================] - 2s 130us/sample - loss: 0.8947 - accuracy: 0.0030 - val_loss: 0.8349 - val_accuracy: 0.0021
# Epoch 13/100
# 11610/11610 [==============================] - 1s 125us/sample - loss: 0.8806 - accuracy: 0.0030 - val_loss: 0.8237 - val_accuracy: 0.0021
# Epoch 14/100
# 11610/11610 [==============================] - 1s 109us/sample - loss: 0.8682 - accuracy: 0.0030 - val_loss: 0.8139 - val_accuracy: 0.0021
# Epoch 15/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.8571 - accuracy: 0.0030 - val_loss: 0.8051 - val_accuracy: 0.0021
# Epoch 16/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.8471 - accuracy: 0.0030 - val_loss: 0.7973 - val_accuracy: 0.0021
# Epoch 17/100
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.8380 - accuracy: 0.0030 - val_loss: 0.7902 - val_accuracy: 0.0021
# Epoch 18/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.8295 - accuracy: 0.0030 - val_loss: 0.7834 - val_accuracy: 0.0021
# Epoch 19/100
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.8216 - accuracy: 0.0030 - val_loss: 0.7772 - val_accuracy: 0.0021
# Epoch 20/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.8140 - accuracy: 0.0030 - val_loss: 0.7712 - val_accuracy: 0.0021
# Epoch 21/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.8067 - accuracy: 0.0030 - val_loss: 0.7658 - val_accuracy: 0.0021
# Epoch 22/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.7998 - accuracy: 0.0030 - val_loss: 0.7605 - val_accuracy: 0.0021
# Epoch 23/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.7934 - accuracy: 0.0030 - val_loss: 0.7556 - val_accuracy: 0.0021
# Epoch 24/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.7872 - accuracy: 0.0030 - val_loss: 0.7509 - val_accuracy: 0.0021
# Epoch 25/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.7813 - accuracy: 0.0030 - val_loss: 0.7463 - val_accuracy: 0.0021
# Epoch 26/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.7756 - accuracy: 0.0030 - val_loss: 0.7420 - val_accuracy: 0.0021
# Epoch 27/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.7701 - accuracy: 0.0030 - val_loss: 0.7376 - val_accuracy: 0.0021
# Epoch 28/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.7647 - accuracy: 0.0030 - val_loss: 0.7335 - val_accuracy: 0.0021
# Epoch 29/100
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.7595 - accuracy: 0.0029 - val_loss: 0.7295 - val_accuracy: 0.0021
# Epoch 30/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.7544 - accuracy: 0.0029 - val_loss: 0.7256 - val_accuracy: 0.0021
# Epoch 31/100
# 11610/11610 [==============================] - 1s 124us/sample - loss: 0.7495 - accuracy: 0.0029 - val_loss: 0.7218 - val_accuracy: 0.0021
# Epoch 32/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.7447 - accuracy: 0.0029 - val_loss: 0.7181 - val_accuracy: 0.0021
# Epoch 33/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.7400 - accuracy: 0.0029 - val_loss: 0.7145 - val_accuracy: 0.0021
# Epoch 34/100
# 11610/11610 [==============================] - 1s 109us/sample - loss: 0.7355 - accuracy: 0.0029 - val_loss: 0.7110 - val_accuracy: 0.0021
# Epoch 35/100
# 11610/11610 [==============================] - 2s 142us/sample - loss: 0.7311 - accuracy: 0.0029 - val_loss: 0.7076 - val_accuracy: 0.0021
# Epoch 36/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.7268 - accuracy: 0.0029 - val_loss: 0.7042 - val_accuracy: 0.0021
# Epoch 37/100
# 11610/11610 [==============================] - 1s 113us/sample - loss: 0.7226 - accuracy: 0.0029 - val_loss: 0.7010 - val_accuracy: 0.0021
# Epoch 38/100
# 11610/11610 [==============================] - 2s 146us/sample - loss: 0.7185 - accuracy: 0.0029 - val_loss: 0.6978 - val_accuracy: 0.0021
# Epoch 39/100
# 11610/11610 [==============================] - 1s 108us/sample - loss: 0.7144 - accuracy: 0.0029 - val_loss: 0.6947 - val_accuracy: 0.0021
# Epoch 40/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.7105 - accuracy: 0.0029 - val_loss: 0.6916 - val_accuracy: 0.0021
# Epoch 41/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.7067 - accuracy: 0.0029 - val_loss: 0.6886 - val_accuracy: 0.0021
# Epoch 42/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.7030 - accuracy: 0.0029 - val_loss: 0.6857 - val_accuracy: 0.0021
# Epoch 43/100
# 11610/11610 [==============================] - 1s 122us/sample - loss: 0.6993 - accuracy: 0.0029 - val_loss: 0.6827 - val_accuracy: 0.0021
# Epoch 44/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.6957 - accuracy: 0.0029 - val_loss: 0.6798 - val_accuracy: 0.0021
# Epoch 45/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.6923 - accuracy: 0.0029 - val_loss: 0.6770 - val_accuracy: 0.0021
# Epoch 46/100
# 11610/11610 [==============================] - 1s 109us/sample - loss: 0.6889 - accuracy: 0.0029 - val_loss: 0.6743 - val_accuracy: 0.0021
# Epoch 47/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.6855 - accuracy: 0.0029 - val_loss: 0.6716 - val_accuracy: 0.0021
# Epoch 48/100
# 11610/11610 [==============================] - 1s 126us/sample - loss: 0.6822 - accuracy: 0.0029 - val_loss: 0.6689 - val_accuracy: 0.0021
# Epoch 49/100
# 11610/11610 [==============================] - 1s 115us/sample - loss: 0.6789 - accuracy: 0.0029 - val_loss: 0.6662 - val_accuracy: 0.0021
# Epoch 50/100
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.6757 - accuracy: 0.0029 - val_loss: 0.6637 - val_accuracy: 0.0021
# Epoch 51/100
# 11610/11610 [==============================] - 2s 132us/sample - loss: 0.6726 - accuracy: 0.0029 - val_loss: 0.6611 - val_accuracy: 0.0021
# Epoch 52/100
# 11610/11610 [==============================] - 2s 132us/sample - loss: 0.6696 - accuracy: 0.0029 - val_loss: 0.6586 - val_accuracy: 0.0021
# Epoch 53/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.6666 - accuracy: 0.0029 - val_loss: 0.6561 - val_accuracy: 0.0021
# Epoch 54/100
# 11610/11610 [==============================] - 1s 125us/sample - loss: 0.6636 - accuracy: 0.0029 - val_loss: 0.6537 - val_accuracy: 0.0021
# Epoch 55/100
# 11610/11610 [==============================] - 1s 121us/sample - loss: 0.6607 - accuracy: 0.0029 - val_loss: 0.6512 - val_accuracy: 0.0021
# Epoch 56/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.6577 - accuracy: 0.0029 - val_loss: 0.6488 - val_accuracy: 0.0021
# Epoch 57/100
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.6549 - accuracy: 0.0029 - val_loss: 0.6464 - val_accuracy: 0.0021
# Epoch 58/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.6521 - accuracy: 0.0029 - val_loss: 0.6441 - val_accuracy: 0.0021
# Epoch 59/100
# 11610/11610 [==============================] - 1s 126us/sample - loss: 0.6493 - accuracy: 0.0029 - val_loss: 0.6418 - val_accuracy: 0.0021
# Epoch 60/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.6465 - accuracy: 0.0029 - val_loss: 0.6394 - val_accuracy: 0.0021
# Epoch 61/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.6438 - accuracy: 0.0029 - val_loss: 0.6372 - val_accuracy: 0.0021
# Epoch 62/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.6411 - accuracy: 0.0029 - val_loss: 0.6349 - val_accuracy: 0.0021
# Epoch 63/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.6385 - accuracy: 0.0029 - val_loss: 0.6327 - val_accuracy: 0.0021
# Epoch 64/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.6359 - accuracy: 0.0029 - val_loss: 0.6305 - val_accuracy: 0.0021
# Epoch 65/100
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.6334 - accuracy: 0.0029 - val_loss: 0.6284 - val_accuracy: 0.0021
# Epoch 66/100
# 11610/11610 [==============================] - 1s 112us/sample - loss: 0.6309 - accuracy: 0.0029 - val_loss: 0.6263 - val_accuracy: 0.0021
# Epoch 67/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.6284 - accuracy: 0.0029 - val_loss: 0.6243 - val_accuracy: 0.0021
# Epoch 68/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.6261 - accuracy: 0.0029 - val_loss: 0.6223 - val_accuracy: 0.0021
# Epoch 69/100
# 11610/11610 [==============================] - 1s 101us/sample - loss: 0.6237 - accuracy: 0.0029 - val_loss: 0.6203 - val_accuracy: 0.0021
# Epoch 70/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.6214 - accuracy: 0.0029 - val_loss: 0.6184 - val_accuracy: 0.0021
# Epoch 71/100
# 11610/11610 [==============================] - 2s 133us/sample - loss: 0.6192 - accuracy: 0.0029 - val_loss: 0.6165 - val_accuracy: 0.0021
# Epoch 72/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.6169 - accuracy: 0.0029 - val_loss: 0.6146 - val_accuracy: 0.0021
# Epoch 73/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.6147 - accuracy: 0.0029 - val_loss: 0.6128 - val_accuracy: 0.0021
# Epoch 74/100
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.6126 - accuracy: 0.0029 - val_loss: 0.6109 - val_accuracy: 0.0021
# Epoch 75/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.6105 - accuracy: 0.0029 - val_loss: 0.6092 - val_accuracy: 0.0021
# Epoch 76/100
# 11610/11610 [==============================] - 1s 127us/sample - loss: 0.6084 - accuracy: 0.0029 - val_loss: 0.6074 - val_accuracy: 0.0021
# Epoch 77/100
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.6063 - accuracy: 0.0029 - val_loss: 0.6057 - val_accuracy: 0.0021
# Epoch 78/100
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.6043 - accuracy: 0.0029 - val_loss: 0.6039 - val_accuracy: 0.0021
# Epoch 79/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.6023 - accuracy: 0.0029 - val_loss: 0.6022 - val_accuracy: 0.0021
# Epoch 80/100
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.6003 - accuracy: 0.0029 - val_loss: 0.6006 - val_accuracy: 0.0021
# Epoch 81/100
# 11610/11610 [==============================] - 1s 115us/sample - loss: 0.5984 - accuracy: 0.0029 - val_loss: 0.5989 - val_accuracy: 0.0021
# Epoch 82/100
# 11610/11610 [==============================] - 1s 111us/sample - loss: 0.5965 - accuracy: 0.0029 - val_loss: 0.5973 - val_accuracy: 0.0021
# Epoch 83/100
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.5946 - accuracy: 0.0029 - val_loss: 0.5957 - val_accuracy: 0.0021
# Epoch 84/100
# 11610/11610 [==============================] - 2s 138us/sample - loss: 0.5927 - accuracy: 0.0029 - val_loss: 0.5941 - val_accuracy: 0.0021
# Epoch 85/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.5909 - accuracy: 0.0029 - val_loss: 0.5925 - val_accuracy: 0.0021
# Epoch 86/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.5890 - accuracy: 0.0029 - val_loss: 0.5910 - val_accuracy: 0.0021
# Epoch 87/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.5872 - accuracy: 0.0029 - val_loss: 0.5895 - val_accuracy: 0.0021
# Epoch 88/100
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.5855 - accuracy: 0.0029 - val_loss: 0.5880 - val_accuracy: 0.0021
# Epoch 89/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.5837 - accuracy: 0.0029 - val_loss: 0.5865 - val_accuracy: 0.0021
# Epoch 90/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.5820 - accuracy: 0.0029 - val_loss: 0.5850 - val_accuracy: 0.0021
# Epoch 91/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.5803 - accuracy: 0.0029 - val_loss: 0.5835 - val_accuracy: 0.0021
# Epoch 92/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.5786 - accuracy: 0.0029 - val_loss: 0.5821 - val_accuracy: 0.0021
# Epoch 93/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5769 - accuracy: 0.0029 - val_loss: 0.5806 - val_accuracy: 0.0021
# Epoch 94/100
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.5752 - accuracy: 0.0029 - val_loss: 0.5792 - val_accuracy: 0.0021
# Epoch 95/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.5735 - accuracy: 0.0029 - val_loss: 0.5778 - val_accuracy: 0.0021
# Epoch 96/100
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.5719 - accuracy: 0.0029 - val_loss: 0.5765 - val_accuracy: 0.0021
# Epoch 97/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5703 - accuracy: 0.0029 - val_loss: 0.5751 - val_accuracy: 0.0021
# Epoch 98/100
# 11610/11610 [==============================] - 1s 110us/sample - loss: 0.5687 - accuracy: 0.0029 - val_loss: 0.5738 - val_accuracy: 0.0021
# Epoch 99/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.5671 - accuracy: 0.0029 - val_loss: 0.5725 - val_accuracy: 0.0021
# Epoch 100/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.5656 - accuracy: 0.0029 - val_loss: 0.5712 - val_accuracy: 0.0021

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.898972110415614, 0.0032945736]
