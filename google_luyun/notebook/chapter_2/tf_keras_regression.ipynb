# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import sys
import time
import sklearn
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for model in mpl, np, pd, sklearn, keras:
    print(model.__name__, model.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=7, micro=7, releaselevel='final', serial=0)
# matplotlib 3.2.2
# numpy 1.19.0
# pandas 1.0.5
# sklearn 0.23.1
# tensorflow_core.keras 2.2.4-tf

# %%
# 回归问题
# 加利福利亚
from sklearn.datasets import fetch_california_housing
#加载数据
housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
import pprint
#展示数据 查看规律
pprint.pprint(housing.data[0:5])
pprint.pprint(housing.target[0:5])
# Out:
# array([[ 8.32520000e+00,  4.10000000e+01,  6.98412698e+00,
#          1.02380952e+00,  3.22000000e+02,  2.55555556e+00,
#          3.78800000e+01, -1.22230000e+02],
#        [ 8.30140000e+00,  2.10000000e+01,  6.23813708e+00,
#          9.71880492e-01,  2.40100000e+03,  2.10984183e+00,
#          3.78600000e+01, -1.22220000e+02],
#        [ 7.25740000e+00,  5.20000000e+01,  8.28813559e+00,
#          1.07344633e+00,  4.96000000e+02,  2.80225989e+00,
#          3.78500000e+01, -1.22240000e+02],
#        [ 5.64310000e+00,  5.20000000e+01,  5.81735160e+00,
#          1.07305936e+00,  5.58000000e+02,  2.54794521e+00,
#          3.78500000e+01, -1.22250000e+02],
#        [ 3.84620000e+00,  5.20000000e+01,  6.28185328e+00,
#          1.08108108e+00,  5.65000000e+02,  2.18146718e+00,
#          3.78500000e+01, -1.22250000e+02]])
# array([4.526, 3.585, 3.521, 3.413, 3.422])

# %%
from sklearn.model_selection import train_test_split

#数据切割 训练集 验证集 测试
x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data, housing.target, random_state=7, test_size=0.25)
x_train, x_valid, y_train, y_valid = train_test_split(x_train_all, y_train_all, random_state=11)

print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

#数据归一化
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_valid_scaled = scaler.transform(x_valid)
x_test_scaled =  scaler.transform(x_test)

# %%
#model构建
model = keras.models.Sequential([
    keras.layers.Dense(50, activation='relu', input_shape=x_train.shape[1:]),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dense(1)
])

model.summary()
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])

callbacks = [keras.callbacks.EarlyStopping(patience=5, min_delta=1e-15)]
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 50)                450
# _________________________________________________________________
# dense_14 (Dense)             (None, 30)                1530
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 2,011
# Trainable params: 2,011
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train_scaled,y_train, validation_data = (x_valid_scaled,y_valid), epochs=100, callbacks = callbacks)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.9222 - accuracy: 0.0031 - val_loss: 0.5756 - val_accuracy: 0.0023
# Epoch 2/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.4758 - accuracy: 0.0031 - val_loss: 0.4798 - val_accuracy: 0.0023
# Epoch 3/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.4255 - accuracy: 0.0031 - val_loss: 0.4260 - val_accuracy: 0.0023
# Epoch 4/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3953 - accuracy: 0.0031 - val_loss: 0.4062 - val_accuracy: 0.0023
# Epoch 5/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3792 - accuracy: 0.0031 - val_loss: 0.3837 - val_accuracy: 0.0023
# Epoch 6/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3683 - accuracy: 0.0031 - val_loss: 0.3756 - val_accuracy: 0.0023
# Epoch 7/100
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3589 - accuracy: 0.0031 - val_loss: 0.3638 - val_accuracy: 0.0023
# Epoch 8/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3514 - accuracy: 0.0031 - val_loss: 0.3581 - val_accuracy: 0.0023
# Epoch 9/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3454 - accuracy: 0.0031 - val_loss: 0.3569 - val_accuracy: 0.0023
# Epoch 10/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3412 - accuracy: 0.0031 - val_loss: 0.3522 - val_accuracy: 0.0023
# Epoch 11/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3349 - accuracy: 0.0031 - val_loss: 0.3523 - val_accuracy: 0.0023
# Epoch 12/100
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3320 - accuracy: 0.0031 - val_loss: 0.3449 - val_accuracy: 0.0023
# Epoch 13/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.3273 - accuracy: 0.0031 - val_loss: 0.3466 - val_accuracy: 0.0023
# Epoch 14/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3252 - accuracy: 0.0031 - val_loss: 0.3382 - val_accuracy: 0.0023
# Epoch 15/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3212 - accuracy: 0.0031 - val_loss: 0.3383 - val_accuracy: 0.0023
# Epoch 16/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3173 - accuracy: 0.0031 - val_loss: 0.3369 - val_accuracy: 0.0023
# Epoch 17/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3142 - accuracy: 0.0031 - val_loss: 0.3322 - val_accuracy: 0.0023
# Epoch 18/100
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.3100 - accuracy: 0.0031 - val_loss: 0.3607 - val_accuracy: 0.0023
# Epoch 19/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3087 - accuracy: 0.0031 - val_loss: 0.3357 - val_accuracy: 0.0023
# Epoch 20/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3048 - accuracy: 0.0031 - val_loss: 0.3229 - val_accuracy: 0.0023
# Epoch 21/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.3031 - accuracy: 0.0031 - val_loss: 0.3296 - val_accuracy: 0.0023
# Epoch 22/100
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.3010 - accuracy: 0.0031 - val_loss: 0.3164 - val_accuracy: 0.0023
# Epoch 23/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.2987 - accuracy: 0.0031 - val_loss: 0.3400 - val_accuracy: 0.0023
# Epoch 24/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.2979 - accuracy: 0.0031 - val_loss: 0.3122 - val_accuracy: 0.0023
# Epoch 25/100
# 11610/11610 [==============================] - 1s 119us/sample - loss: 0.2955 - accuracy: 0.0031 - val_loss: 0.3162 - val_accuracy: 0.0023
# Epoch 26/100
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.2954 - accuracy: 0.0031 - val_loss: 0.3152 - val_accuracy: 0.0023
# Epoch 27/100
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.2936 - accuracy: 0.0031 - val_loss: 0.3140 - val_accuracy: 0.0023
# Epoch 28/100
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.2906 - accuracy: 0.0031 - val_loss: 0.3114 - val_accuracy: 0.0023
# Epoch 29/100
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.2897 - accuracy: 0.0031 - val_loss: 0.3094 - val_accuracy: 0.0023
# Epoch 30/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.2888 - accuracy: 0.0031 - val_loss: 0.3096 - val_accuracy: 0.0023
# Epoch 31/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.2878 - accuracy: 0.0030 - val_loss: 0.3061 - val_accuracy: 0.0023
# Epoch 32/100
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.2871 - accuracy: 0.0031 - val_loss: 0.3066 - val_accuracy: 0.0023
# Epoch 33/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.2851 - accuracy: 0.0031 - val_loss: 0.3052 - val_accuracy: 0.0023
# Epoch 34/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.2856 - accuracy: 0.0031 - val_loss: 0.3088 - val_accuracy: 0.0023
# Epoch 35/100
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.2832 - accuracy: 0.0030 - val_loss: 0.3000 - val_accuracy: 0.0023
# Epoch 36/100
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.2837 - accuracy: 0.0030 - val_loss: 0.3047 - val_accuracy: 0.0023
# Epoch 37/100
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.2823 - accuracy: 0.0030 - val_loss: 0.3006 - val_accuracy: 0.0023
# Epoch 38/100
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.2808 - accuracy: 0.0030 - val_loss: 0.3142 - val_accuracy: 0.0023
# Epoch 39/100
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.2811 - accuracy: 0.0030 - val_loss: 0.3028 - val_accuracy: 0.0023
# Epoch 40/100
# 11610/11610 [==============================] - 1s 77us/sample - loss: 0.2799 - accuracy: 0.0031 - val_loss: 0.3047 - val_accuracy: 0.0023

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.31452162335085315, 0.0032945736]
